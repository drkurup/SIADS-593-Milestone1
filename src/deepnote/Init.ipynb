# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# pip install --upgrade pip
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Requirement already satisfied: pip in /root/venv/lib/python3.9/site-packages (23.0.1)
# Collecting pip
#   Downloading pip-24.0-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 23.7 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.0.1
#     Uninstalling pip-23.0.1:
#       Successfully uninstalled pip-23.0.1
# Successfully installed pip-24.0
# Collecting opencage (from -r ./requirements.txt (line 1))
#   Downloading opencage-2.4.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting import-ipynb (from -r ./requirements.txt (line 2))
#   Downloading import_ipynb-0.1.4-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: pandas in /shared-libs/python3.9/py/lib/python3.9/site-packages (from -r ./requirements.txt (line 3)) (2.1.4)
# Collecting ipywidgets (from -r ./requirements.txt (line 4))
#   Downloading ipywidgets-8.1.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting ydata-profiling (from -r ./requirements.txt (line 5))
#   Downloading ydata_profiling-4.8.3-py2.py3-none-any.whl.metadata (20 kB)
# Collecting lux-api (from -r ./requirements.txt (line 6))
#   Downloading lux-api-0.5.1.tar.gz (127 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.0/127.0 kB 13.4 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting watermark (from -r ./requirements.txt (line 7))
#   Downloading watermark-2.4.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting sweetviz (from -r ./requirements.txt (line 8))
#   Downloading sweetviz-2.3.1-py3-none-any.whl.metadata (24 kB)
# Collecting Requests>=2.31.0 (from opencage->-r ./requirements.txt (line 1))
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting backoff>=2.2.1 (from opencage->-r ./requirements.txt (line 1))
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: IPython in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from import-ipynb->-r ./requirements.txt (line 2)) (8.5.0)
# Requirement already satisfied: nbformat in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from import-ipynb->-r ./requirements.txt (line 2)) (5.7.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas->-r ./requirements.txt (line 3)) (1.23.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pandas->-r ./requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas->-r ./requirements.txt (line 3)) (2022.5)
# Requirement already satisfied: tzdata>=2022.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas->-r ./requirements.txt (line 3)) (2022.5)
# Collecting comm>=0.1.3 (from ipywidgets->-r ./requirements.txt (line 4))
#   Downloading comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: traitlets>=4.3.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipywidgets->-r ./requirements.txt (line 4)) (5.5.0)
# Collecting widgetsnbextension~=4.0.11 (from ipywidgets->-r ./requirements.txt (line 4))
#   Downloading widgetsnbextension-4.0.11-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.11 (from ipywidgets->-r ./requirements.txt (line 4))
#   Downloading jupyterlab_widgets-3.0.11-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: scipy<1.14,>=1.4.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from ydata-profiling->-r ./requirements.txt (line 5)) (1.9.3)
# Requirement already satisfied: matplotlib<3.9,>=3.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from ydata-profiling->-r ./requirements.txt (line 5)) (3.6.0)
# Collecting pydantic>=2 (from ydata-profiling->-r ./requirements.txt (line 5))
#   Downloading pydantic-2.7.4-py3-none-any.whl.metadata (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.4/109.4 kB 20.0 MB/s eta 0:00:00
# Collecting PyYAML<6.1,>=5.0.0 (from ydata-profiling->-r ./requirements.txt (line 5))
#   Downloading PyYAML-6.0.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ydata-profiling->-r ./requirements.txt (line 5)) (3.1.2)
# Collecting visions<0.7.7,>=0.7.5 (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling->-r ./requirements.txt (line 5))
#   Downloading visions-0.7.6-py3-none-any.whl.metadata (11 kB)
# Collecting htmlmin==0.1.12 (from ydata-profiling->-r ./requirements.txt (line 5))
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling->-r ./requirements.txt (line 5))
#   Downloading phik-0.12.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from ydata-profiling->-r ./requirements.txt (line 5)) (4.64.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from ydata-profiling->-r ./requirements.txt (line 5)) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling->-r ./requirements.txt (line 5))
#   Downloading multimethod-1.11.2-py3-none-any.whl.metadata (9.1 kB)
# Collecting statsmodels<1,>=0.13.2 (from ydata-profiling->-r ./requirements.txt (line 5))
#   Downloading statsmodels-0.14.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Collecting typeguard<5,>=3 (from ydata-profiling->-r ./requirements.txt (line 5))
#   Downloading typeguard-4.3.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting imagehash==4.3.1 (from ydata-profiling->-r ./requirements.txt (line 5))
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting wordcloud>=1.9.1 (from ydata-profiling->-r ./requirements.txt (line 5))
#   Downloading wordcloud-1.9.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting dacite>=1.8 (from ydata-profiling->-r ./requirements.txt (line 5))
#   Downloading dacite-1.8.1-py3-none-any.whl.metadata (15 kB)
# Collecting numba<1,>=0.56.0 (from ydata-profiling->-r ./requirements.txt (line 5))
#   Downloading numba-0.59.1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.7 kB)
# Collecting PyWavelets (from imagehash==4.3.1->ydata-profiling->-r ./requirements.txt (line 5))
#   Downloading pywavelets-1.6.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: pillow in /shared-libs/python3.9/py/lib/python3.9/site-packages (from imagehash==4.3.1->ydata-profiling->-r ./requirements.txt (line 5)) (9.2.0)
# Requirement already satisfied: altair>=4.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from lux-api->-r ./requirements.txt (line 6)) (4.2.2)
# Requirement already satisfied: scikit-learn>=0.22 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from lux-api->-r ./requirements.txt (line 6)) (1.1.2)
# Collecting lux-widget>=0.1.4 (from lux-api->-r ./requirements.txt (line 6))
#   Downloading lux-widget-0.1.11.tar.gz (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 90.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting autopep8>=1.5 (from lux-api->-r ./requirements.txt (line 6))
#   Downloading autopep8-2.2.0-py2.py3-none-any.whl.metadata (16 kB)
# Collecting iso3166 (from lux-api->-r ./requirements.txt (line 6))
#   Downloading iso3166-2.1.1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: psutil>=5.9.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from lux-api->-r ./requirements.txt (line 6)) (5.9.3)
# Collecting sh (from lux-api->-r ./requirements.txt (line 6))
#   Downloading sh-2.0.7-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: importlib-metadata>=1.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from watermark->-r ./requirements.txt (line 7)) (5.0.0)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.9/site-packages (from watermark->-r ./requirements.txt (line 7)) (58.1.0)
# Collecting importlib-resources>=1.2.0 (from sweetviz->-r ./requirements.txt (line 8))
#   Downloading importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: entrypoints in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from altair>=4.0.0->lux-api->-r ./requirements.txt (line 6)) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from altair>=4.0.0->lux-api->-r ./requirements.txt (line 6)) (3.2.0)
# Requirement already satisfied: toolz in /shared-libs/python3.9/py/lib/python3.9/site-packages (from altair>=4.0.0->lux-api->-r ./requirements.txt (line 6)) (0.12.0)
# Collecting pycodestyle>=2.11.0 (from autopep8>=1.5->lux-api->-r ./requirements.txt (line 6))
#   Downloading pycodestyle-2.11.1-py2.py3-none-any.whl.metadata (4.5 kB)
# Collecting tomli (from autopep8>=1.5->lux-api->-r ./requirements.txt (line 6))
#   Downloading tomli-2.0.1-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from importlib-metadata>=1.4->watermark->-r ./requirements.txt (line 7)) (3.9.0)
# Requirement already satisfied: backcall in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from IPython->import-ipynb->-r ./requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: decorator in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from IPython->import-ipynb->-r ./requirements.txt (line 2)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from IPython->import-ipynb->-r ./requirements.txt (line 2)) (0.17.2)
# Requirement already satisfied: matplotlib-inline in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from IPython->import-ipynb->-r ./requirements.txt (line 2)) (0.1.6)
# Requirement already satisfied: pickleshare in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from IPython->import-ipynb->-r ./requirements.txt (line 2)) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from IPython->import-ipynb->-r ./requirements.txt (line 2)) (3.0.31)
# Requirement already satisfied: pygments>=2.4.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from IPython->import-ipynb->-r ./requirements.txt (line 2)) (2.13.0)
# Requirement already satisfied: stack-data in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from IPython->import-ipynb->-r ./requirements.txt (line 2)) (0.5.1)
# Requirement already satisfied: pexpect>4.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from IPython->import-ipynb->-r ./requirements.txt (line 2)) (4.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->-r ./requirements.txt (line 5)) (2.0.0)
# Requirement already satisfied: notebook>=4.0.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (6.5.5)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling->-r ./requirements.txt (line 5)) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling->-r ./requirements.txt (line 5)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling->-r ./requirements.txt (line 5)) (4.37.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling->-r ./requirements.txt (line 5)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling->-r ./requirements.txt (line 5)) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling->-r ./requirements.txt (line 5)) (3.0.9)
# Collecting llvmlite<0.43,>=0.42.0dev0 (from numba<1,>=0.56.0->ydata-profiling->-r ./requirements.txt (line 5))
#   Downloading llvmlite-0.42.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: joblib>=0.14.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from phik<0.13,>=0.11.1->ydata-profiling->-r ./requirements.txt (line 5)) (1.2.0)
# Collecting annotated-types>=0.4.0 (from pydantic>=2->ydata-profiling->-r ./requirements.txt (line 5))
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.18.4 (from pydantic>=2->ydata-profiling->-r ./requirements.txt (line 5))
#   Downloading pydantic_core-2.18.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Collecting typing-extensions>=4.6.1 (from pydantic>=2->ydata-profiling->-r ./requirements.txt (line 5))
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->-r ./requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from Requests>=2.31.0->opencage->-r ./requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from Requests>=2.31.0->opencage->-r ./requirements.txt (line 1)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from Requests>=2.31.0->opencage->-r ./requirements.txt (line 1)) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from Requests>=2.31.0->opencage->-r ./requirements.txt (line 1)) (2022.9.24)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn>=0.22->lux-api->-r ./requirements.txt (line 6)) (3.1.0)
# Collecting patsy>=0.5.6 (from statsmodels<1,>=0.13.2->ydata-profiling->-r ./requirements.txt (line 5))
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: attrs>=19.3.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling->-r ./requirements.txt (line 5)) (22.1.0)
# Collecting networkx>=2.4 (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling->-r ./requirements.txt (line 5))
#   Downloading networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# WARNING: visions 0.7.6 does not provide the extra 'type-image-path'
# Requirement already satisfied: fastjsonschema in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbformat->import-ipynb->-r ./requirements.txt (line 2)) (2.16.2)
# Requirement already satisfied: jupyter-core in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbformat->import-ipynb->-r ./requirements.txt (line 2)) (4.11.2)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jedi>=0.16->IPython->import-ipynb->-r ./requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api->-r ./requirements.txt (line 6)) (0.18.1)
# Requirement already satisfied: tornado>=6.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (6.2)
# Requirement already satisfied: pyzmq<25,>=17 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (24.0.1)
# Requirement already satisfied: argon2-cffi in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (21.3.0)
# Requirement already satisfied: jupyter-client<8,>=5.3.4 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (7.4.3)
# Requirement already satisfied: ipython-genutils in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: nbconvert>=5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (6.4.5)
# Requirement already satisfied: nest-asyncio>=1.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (1.5.6)
# Requirement already satisfied: ipykernel in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (6.16.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (0.16.0)
# Requirement already satisfied: prometheus-client in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (0.15.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pexpect>4.3->IPython->import-ipynb->-r ./requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: wcwidth in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>3.0.1->IPython->import-ipynb->-r ./requirements.txt (line 2)) (0.2.5)
# Requirement already satisfied: executing in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from stack-data->IPython->import-ipynb->-r ./requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: asttokens in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from stack-data->IPython->import-ipynb->-r ./requirements.txt (line 2)) (2.0.8)
# Requirement already satisfied: pure-eval in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from stack-data->IPython->import-ipynb->-r ./requirements.txt (line 2)) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (1.21.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (0.2.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (0.2.2)
# Requirement already satisfied: bleach in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (5.0.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (1.5.0)
# Requirement already satisfied: testpath in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (0.6.0)
# Requirement already satisfied: defusedxml in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (4.11.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (0.5.13)
# Requirement already satisfied: argon2-cffi-bindings in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (21.2.0)
# Requirement already satisfied: debugpy>=1.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (1.6.3)
# Requirement already satisfied: anyio<4,>=3.1.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (3.6.2)
# Requirement already satisfied: websocket-client in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (1.4.1)
# Requirement already satisfied: cffi>=1.0.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (2.3.2.post1)
# Requirement already satisfied: webencodings in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from bleach->nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: pycparser in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r ./requirements.txt (line 6)) (2.21)
# Downloading opencage-2.4.0-py3-none-any.whl (16 kB)
# Downloading import_ipynb-0.1.4-py3-none-any.whl (4.1 kB)
# Downloading ipywidgets-8.1.3-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 24.5 MB/s eta 0:00:00
# Downloading ydata_profiling-4.8.3-py2.py3-none-any.whl (359 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 359.5/359.5 kB 44.0 MB/s eta 0:00:00
# Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 38.3 MB/s eta 0:00:00
# Downloading watermark-2.4.3-py2.py3-none-any.whl (7.6 kB)
# Downloading sweetviz-2.3.1-py3-none-any.whl (15.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 104.6 MB/s eta 0:00:00
# Downloading autopep8-2.2.0-py2.py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 7.0 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading comm-0.2.2-py3-none-any.whl (7.2 kB)
# Downloading dacite-1.8.1-py3-none-any.whl (14 kB)
# Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Downloading jupyterlab_widgets-3.0.11-py3-none-any.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 kB 26.9 MB/s eta 0:00:00
# Downloading multimethod-1.11.2-py3-none-any.whl (10 kB)
# Downloading numba-0.59.1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 82.0 MB/s eta 0:00:00
# Downloading phik-0.12.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (686 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.3/686.3 kB 56.2 MB/s eta 0:00:00
# Downloading pydantic-2.7.4-py3-none-any.whl (409 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.0/409.0 kB 45.6 MB/s eta 0:00:00
# Downloading pydantic_core-2.18.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 97.4 MB/s eta 0:00:00
# Downloading PyYAML-6.0.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (738 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 738.9/738.9 kB 23.8 MB/s eta 0:00:00
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 10.0 MB/s eta 0:00:00
# Downloading statsmodels-0.14.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 110.7 MB/s eta 0:00:00
# Downloading typeguard-4.3.0-py3-none-any.whl (35 kB)
# Downloading visions-0.7.6-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 20.0 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.11-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 104.4 MB/s eta 0:00:00
# Downloading wordcloud-1.9.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (513 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 513.6/513.6 kB 40.8 MB/s eta 0:00:00
# Downloading iso3166-2.1.1-py3-none-any.whl (9.8 kB)
# Downloading sh-2.0.7-py3-none-any.whl (38 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading llvmlite-0.42.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 MB 48.3 MB/s eta 0:00:00
# Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 90.3 MB/s eta 0:00:00
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.9/233.9 kB 37.5 MB/s eta 0:00:00
# Downloading pycodestyle-2.11.1-py2.py3-none-any.whl (31 kB)
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading pywavelets-1.6.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 104.9 MB/s eta 0:00:00
# Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Building wheels for collected packages: htmlmin, lux-api, lux-widget
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27098 sha256=0a64dba708e5ddebb84ffa5455be5d2d732d9157541a5025d4cc1d7947d106f1
#   Stored in directory: /root/.cache/pip/wheels/1d/05/04/c6d7d3b66539d9e659ac6dfe81e2d0fd4c1a8316cc5a403300
#   Building wheel for lux-api (pyproject.toml): started
#   Building wheel for lux-api (pyproject.toml): finished with status 'done'
#   Created wheel for lux-api: filename=lux_api-0.5.1-py3-none-any.whl size=185603 sha256=28e18f55b533f86f9895ea836ba74e5b91a2ed0e8ac6a97701ae001c18d3a73f
#   Stored in directory: /root/.cache/pip/wheels/bd/05/a4/441d23d1cece85d6cd3cec43b38896e88a729e8048138825bd
#   Building wheel for lux-widget (setup.py): started
#   Building wheel for lux-widget (setup.py): finished with status 'done'
#   Created wheel for lux-widget: filename=lux_widget-0.1.11-py3-none-any.whl size=2540461 sha256=e3a3596f996254edd351f16f6af8fd0e0c9653165fb97fb336b7d38630f05be4
#   Stored in directory: /root/.cache/pip/wheels/03/dd/c3/286c3ca89a08533a99b0eb3f6e9a4b4c23476202c5a3fd622e
# Successfully built htmlmin lux-api lux-widget
# Installing collected packages: htmlmin, widgetsnbextension, typing-extensions, tomli, sh, Requests, PyYAML, PyWavelets, pycodestyle, patsy, networkx, multimethod, llvmlite, jupyterlab-widgets, iso3166, importlib-resources, dacite, comm, backoff, annotated-types, typeguard, pydantic-core, opencage, numba, imagehash, autopep8, wordcloud, visions, sweetviz, statsmodels, pydantic, phik, watermark, ipywidgets, import-ipynb, ydata-profiling, lux-widget, lux-api
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.4.0
#     Not uninstalling typing-extensions at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'typing_extensions'. No files were found to uninstall.
#   Attempting uninstall: Requests
#     Found existing installation: requests 2.28.1
#     Not uninstalling requests at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'requests'. No files were found to uninstall.
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.2
#     Not uninstalling pydantic at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'pydantic'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# confection 0.0.3 requires pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4, but you have pydantic 2.7.4 which is incompatible.
# google-cloud-spanner 3.36.0 requires sqlparse>=0.4.4, but you have sqlparse 0.4.3 which is incompatible.
# spacy 3.4.2 requires pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4, but you have pydantic 2.7.4 which is incompatible.
# thinc 8.1.5 requires pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4, but you have pydantic 2.7.4 which is incompatible.
# Successfully installed PyWavelets-1.6.0 PyYAML-6.0.1 Requests-2.32.3 annotated-types-0.7.0 autopep8-2.2.0 backoff-2.2.1 comm-0.2.2 dacite-1.8.1 htmlmin-0.1.12 imagehash-4.3.1 import-ipynb-0.1.4 importlib-resources-6.4.0 ipywidgets-8.1.3 iso3166-2.1.1 jupyterlab-widgets-3.0.11 llvmlite-0.42.0 lux-api-0.5.1 lux-widget-0.1.11 multimethod-1.11.2 networkx-3.2.1 numba-0.59.1 opencage-2.4.0 patsy-0.5.6 phik-0.12.4 pycodestyle-2.11.1 pydantic-2.7.4 pydantic-core-2.18.4 sh-2.0.7 statsmodels-0.14.2 sweetviz-2.3.1 tomli-2.0.1 typeguard-4.3.0 typing-extensions-4.12.2 visions-0.7.6 watermark-2.4.3 widgetsnbextension-4.0.11 wordcloud-1.9.3 ydata-profiling-4.8.3

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7862ac62-05ae-412f-9bc1-59d586e87203' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
