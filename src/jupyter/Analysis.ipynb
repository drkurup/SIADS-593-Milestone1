# %% [markdown]
# # Analysis of Ridership Project
#
# ## Importing Necessary Libraries and Modules
#
# In this project, we will analyze the ridership data to uncover trends and insights. We need to import several libraries and modules that will assist us in data collection, cleaning, visualization, and statistical analysis.
#
# ### Custom Modules
#
# From the custom module `siads_593_milestone1.deepnote.Data_Collection_And_Cleaning`, we import:
# - `primary_dataset_cleaning`: Function for cleaning the primary dataset.
# - `secondary_dataset_cleaning`: Function for cleaning the secondary dataset.
# - `tertiary_dataset_cleaning`: Function for cleaning the tertiary dataset.
# - `final_merge_df`: Function for merging the cleaned datasets into a final DataFrame.

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: opencage in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: import-ipynb in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (0.1.4)
# Requirement already satisfied: pandas in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (2.2.2)
# Requirement already satisfied: ipywidgets in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (7.6.5)
# Requirement already satisfied: ydata-profiling in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (4.8.3)
# Requirement already satisfied: lux-api in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (0.5.1)
# Requirement already satisfied: watermark in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (2.4.3)
# Requirement already satisfied: sweetviz in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (2.3.1)
# Requirement already satisfied: Requests>=2.31.0 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from opencage->-r requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: backoff>=2.2.1 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from opencage->-r requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: IPython in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from import-ipynb->-r requirements.txt (line 2)) (7.31.1)
# Requirement already satisfied: nbformat in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from import-ipynb->-r requirements.txt (line 2)) (5.5.0)
# Requirement already satisfied: numpy>=1.22.4 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 3)) (1.24.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 3)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 3)) (2024.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets->-r requirements.txt (line 4)) (6.15.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets->-r requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets->-r requirements.txt (line 4)) (5.1.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets->-r requirements.txt (line 4)) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets->-r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: scipy<1.14,>=1.4.1 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling->-r requirements.txt (line 5)) (1.9.1)
# Requirement already satisfied: matplotlib<3.9,>=3.2 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling->-r requirements.txt (line 5)) (3.5.2)
# Requirement already satisfied: pydantic>=2 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling->-r requirements.txt (line 5)) (2.7.4)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling->-r requirements.txt (line 5)) (6.0)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling->-r requirements.txt (line 5)) (2.11.3)
# Requirement already satisfied: visions<0.7.7,>=0.7.5 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling->-r requirements.txt (line 5)) (0.7.6)
# Requirement already satisfied: htmlmin==0.1.12 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling->-r requirements.txt (line 5)) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling->-r requirements.txt (line 5)) (0.12.4)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling->-r requirements.txt (line 5)) (4.64.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling->-r requirements.txt (line 5)) (0.11.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling->-r requirements.txt (line 5)) (1.11.2)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling->-r requirements.txt (line 5)) (0.13.2)
# Requirement already satisfied: typeguard<5,>=3 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling->-r requirements.txt (line 5)) (4.3.0)
# Requirement already satisfied: imagehash==4.3.1 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling->-r requirements.txt (line 5)) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.1 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling->-r requirements.txt (line 5)) (1.9.3)
# Requirement already satisfied: dacite>=1.8 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling->-r requirements.txt (line 5)) (1.8.1)
# Requirement already satisfied: numba<1,>=0.56.0 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling->-r requirements.txt (line 5)) (0.59.0)
# Requirement already satisfied: PyWavelets in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from imagehash==4.3.1->ydata-profiling->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: pillow in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from imagehash==4.3.1->ydata-profiling->-r requirements.txt (line 5)) (10.3.0)
# Requirement already satisfied: altair>=4.0.0 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from lux-api->-r requirements.txt (line 6)) (5.2.0)
# Requirement already satisfied: scikit-learn>=0.22 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from lux-api->-r requirements.txt (line 6)) (1.0.2)
# Requirement already satisfied: lux-widget>=0.1.4 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from lux-api->-r requirements.txt (line 6)) (0.1.11)
# Requirement already satisfied: autopep8>=1.5 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from lux-api->-r requirements.txt (line 6)) (1.6.0)
# Requirement already satisfied: iso3166 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from lux-api->-r requirements.txt (line 6)) (2.1.1)
# Requirement already satisfied: psutil>=5.9.0 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from lux-api->-r requirements.txt (line 6)) (5.9.0)
# Requirement already satisfied: sh in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from lux-api->-r requirements.txt (line 6)) (2.0.7)
# Requirement already satisfied: importlib-metadata>=1.4 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from watermark->-r requirements.txt (line 7)) (5.2.0)
# Requirement already satisfied: setuptools in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from watermark->-r requirements.txt (line 7)) (63.4.1)
# Requirement already satisfied: importlib-resources>=1.2.0 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from sweetviz->-r requirements.txt (line 8)) (5.13.0)
# Requirement already satisfied: jsonschema>=3.0 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from altair>=4.0.0->lux-api->-r requirements.txt (line 6)) (4.16.0)
# Requirement already satisfied: packaging in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from altair>=4.0.0->lux-api->-r requirements.txt (line 6)) (21.3)
# Requirement already satisfied: toolz in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from altair>=4.0.0->lux-api->-r requirements.txt (line 6)) (0.11.2)
# Requirement already satisfied: typing-extensions>=4.0.1 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from altair>=4.0.0->lux-api->-r requirements.txt (line 6)) (4.12.0)
# Requirement already satisfied: pycodestyle>=2.8.0 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from autopep8>=1.5->lux-api->-r requirements.txt (line 6)) (2.8.0)
# Requirement already satisfied: toml in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from autopep8>=1.5->lux-api->-r requirements.txt (line 6)) (0.10.2)
# Requirement already satisfied: zipp>=0.5 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=1.4->watermark->-r requirements.txt (line 7)) (3.8.0)
# Requirement already satisfied: appnope in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 4)) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 4)) (1.5.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 4)) (7.3.4)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 4)) (0.1.6)
# Requirement already satisfied: nest-asyncio in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 4)) (1.5.5)
# Requirement already satisfied: pyzmq>=17 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 4)) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 4)) (6.1)
# Requirement already satisfied: jedi>=0.16 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb->-r requirements.txt (line 2)) (0.18.1)
# Requirement already satisfied: decorator in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb->-r requirements.txt (line 2)) (5.1.1)
# Requirement already satisfied: pickleshare in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb->-r requirements.txt (line 2)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb->-r requirements.txt (line 2)) (3.0.20)
# Requirement already satisfied: pygments in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb->-r requirements.txt (line 2)) (2.17.2)
# Requirement already satisfied: backcall in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb->-r requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb->-r requirements.txt (line 2)) (4.8.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->-r requirements.txt (line 5)) (2.0.1)
# Requirement already satisfied: notebook>=4.0.0 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from lux-widget>=0.1.4->lux-api->-r requirements.txt (line 6)) (6.4.12)
# Requirement already satisfied: cycler>=0.10 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling->-r requirements.txt (line 5)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling->-r requirements.txt (line 5)) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling->-r requirements.txt (line 5)) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<3.9,>=3.2->ydata-profiling->-r requirements.txt (line 5)) (3.0.9)
# Requirement already satisfied: fastjsonschema in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from nbformat->import-ipynb->-r requirements.txt (line 2)) (2.16.2)
# Requirement already satisfied: jupyter_core in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from nbformat->import-ipynb->-r requirements.txt (line 2)) (4.11.1)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from numba<1,>=0.56.0->ydata-profiling->-r requirements.txt (line 5)) (0.42.0)
# Requirement already satisfied: joblib>=0.14.1 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from phik<0.13,>=0.11.1->ydata-profiling->-r requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from pydantic>=2->ydata-profiling->-r requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from pydantic>=2->ydata-profiling->-r requirements.txt (line 5)) (2.18.4)
# Requirement already satisfied: six>=1.5 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from Requests>=2.31.0->opencage->-r requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from Requests>=2.31.0->opencage->-r requirements.txt (line 1)) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from Requests>=2.31.0->opencage->-r requirements.txt (line 1)) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from Requests>=2.31.0->opencage->-r requirements.txt (line 1)) (2022.9.24)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.22->lux-api->-r requirements.txt (line 6)) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling->-r requirements.txt (line 5)) (0.5.2)
# Requirement already satisfied: attrs>=19.3.0 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling->-r requirements.txt (line 5)) (21.4.0)
# Requirement already satisfied: networkx>=2.4 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling->-r requirements.txt (line 5)) (2.8.4)
# WARNING: visions 0.7.6 does not provide the extra 'type-image-path'
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->IPython->import-ipynb->-r requirements.txt (line 2)) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api->-r requirements.txt (line 6)) (0.18.0)
# Requirement already satisfied: entrypoints in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 4)) (0.4)
# Requirement already satisfied: argon2-cffi in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r requirements.txt (line 6)) (21.3.0)
# Requirement already satisfied: nbconvert>=5 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r requirements.txt (line 6)) (6.4.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r requirements.txt (line 6)) (0.13.1)
# Requirement already satisfied: prometheus-client in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r requirements.txt (line 6)) (0.14.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->IPython->import-ipynb->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->import-ipynb->-r requirements.txt (line 2)) (0.2.5)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r requirements.txt (line 6)) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r requirements.txt (line 6)) (0.1.2)
# Requirement already satisfied: bleach in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r requirements.txt (line 6)) (4.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r requirements.txt (line 6)) (1.5.0)
# Requirement already satisfied: testpath in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r requirements.txt (line 6)) (0.6.0)
# Requirement already satisfied: defusedxml in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r requirements.txt (line 6)) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r requirements.txt (line 6)) (4.11.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r requirements.txt (line 6)) (0.5.13)
# Requirement already satisfied: argon2-cffi-bindings in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r requirements.txt (line 6)) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r requirements.txt (line 6)) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r requirements.txt (line 6)) (2.3.1)
# Requirement already satisfied: webencodings in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r requirements.txt (line 6)) (0.5.1)
# Requirement already satisfied: pycparser in /Users/deepthikurup/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.0.0->lux-widget>=0.1.4->lux-api->-r requirements.txt (line 6)) (2.21)

# %%
import import_ipynb
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from ydata_profiling import ProfileReport
from scipy.stats import pearsonr
from IPython.display import display

# %matplotlib inline

# %% [markdown]
# The below steps are added just for the deepnote notebook to run in Jupyter. The directory path is finding for import

# %%
# Add the parent directory to the Python path
import sys
import os

# Get the current working directory
current_dir = os.getcwd()

# Get the parent directory
parent_dir = os.path.dirname(current_dir)

# Add the parent directory to the Python path
sys.path.append(parent_dir)

from Data_Collection_And_Cleaning import (
    primary_dataset_cleaning, 
    secondary_dataset_cleaning, 
    tertiary_dataset_cleaning, 
    final_merge_df)

# %% [markdown]
# ## Population Summary Statistics
#
# In this cell, we define a function `population_summary_stats` that computes and returns summary statistics for the population data across different census years (2000, 2010, and 2020). This function uses the `secondary_dataset_cleaning` function to obtain the cleaned population dataset.
#
# ### Function: `population_summary_stats`

# %%
# Population Summary Stats

def population_summary_stats():
    
    # Get population by Zip Code
    population_df = secondary_dataset_cleaning()

    # 2000 Min/Max Zip Codes
    max_2000 = population_df.loc[population_df['2000 Population'] == population_df['2000 Population'].max()]
    min_2000 = population_df.loc[population_df['2000 Population'] == population_df['2000 Population'].min()]

    # 2010 Min/Max Zip Codes
    max_2010 = population_df.loc[population_df['2010 Population'] == population_df['2010 Population'].max()]
    min_2010 = population_df.loc[population_df['2010 Population'] == population_df['2010 Population'].min()]

    # 2020 Min/Max Zip Codes
    max_2020 = population_df.loc[population_df['2020 Population'] == population_df['2020 Population'].max()]
    min_2020 = population_df.loc[population_df['2020 Population'] == population_df['2020 Population'].min()]

    #Max and Min Populations in each census year
    summary_df = pd.DataFrame()
    summary_df = pd.concat([max_2000, min_2000, max_2010, min_2010, max_2020, min_2020], ignore_index = True)
    summary_df.index = ['2000 Max Population ZIP', '2000 Min Population ZIP', '2010 Max Population ZIP',
    '2010 Min Population ZIP', '2020 Max Population ZIP', '2020 Min Population ZIP']

    return summary_df

# %% [markdown]
# ## Function to Calculate Ridership Summary Statistics
#
# In this cell, we define a function `ridership_summary_stats` that calculates the maximum and minimum monthly ridership statistics from the primary dataset.
#
# Please note that `IPyWidgets are not supported` in deepnote and igore the warning

# %%
def ridership_summary_stats():
    df = primary_dataset_cleaning()

    months = df['MONTH_BEGINNING'].unique()
    max_result_df = pd.DataFrame()
    min_result_df = pd.DataFrame()

    for month in months:
        monthly_data = df[df['MONTH_BEGINNING'] == month]
        
        # Find the row with the maximum value in MONTHTOTAL
        max_row = monthly_data.loc[monthly_data['MONTHTOTAL'].idxmax()]
        max_result_df = pd.concat([max_result_df, max_row.to_frame().T], ignore_index=True)
        
        # Find the row with the minimum value in MONTHTOTAL
        min_row = monthly_data.loc[monthly_data['MONTHTOTAL'].idxmin()]
        min_result_df = pd.concat([min_result_df, min_row.to_frame().T], ignore_index=True)

    return max_result_df, min_result_df

# %% [markdown]
# # Data Profiling Reports
#
# In this, we generate profiling reports for four datasets: `primary_dataset`, `secondary_dataset`, `tertiary_dataset`, and `merged_df_dataset`. These reports provide detailed insights into the datasets
# <span style="color: red;">The generation of HTML is commented out to not display IPWidget warning. Please refer to `src/report/NAME_OF_DATASET_dataset_profiling.html` for the generated report </span>

# %%
primary_dataset_df = primary_dataset_cleaning()
primary_dataset_profiling = ProfileReport(primary_dataset_df, title="Pandas Profiling report")

#primary_dataset_profiling.to_file("../src/reports/primary_dataset_profiling.html")

# %%
secondary_dataset_df = secondary_dataset_cleaning()
secondary_dataset_profiling = ProfileReport(secondary_dataset_df, title="Pandas Profiling report")

#secondary_dataset_profiling.to_file("../reports/secondary_dataset_profiling.html")

# %%
tertiary_dataset_df = tertiary_dataset_cleaning()
tertiary_dataset_profiling = ProfileReport(tertiary_dataset_df, title="Pandas Profiling report")

#tertiary_dataset_profiling.to_file("../reports/tertiary_dataset_profiling.html")

# %%
final_merge_df_profiling = ProfileReport(final_merge_df, title="Pandas Profiling report")

#final_merge_df_profiling.to_file("../reports/final_merge_dataset_profiling1.html")

# %% [markdown]
# ## Data Cleaning: Removing Missing Values
#
# Now, we proceed with cleaning our final merged dataset by removing any rows that contain missing values.

# %%
final_merge_df.dropna(inplace=True)

# %% [markdown]
# ## Calculating Pearson Correlation Coefficient
#
# We calculate the Pearson correlation coefficient between the total monthly ridership and the population for different years (2000, 2010, and 2020). The Pearson correlation coefficient measures the linear correlation between two variables, giving a value between -1 and 1, where 1 indicates a perfect positive linear relationship, -1 indicates a perfect negative linear relationship, and 0 indicates no linear relationship.

# %%
# Calculate Pearson correlation for each year
correlation_2000 = pearsonr(final_merge_df['MONTHTOTAL'], final_merge_df['2000 Population'])
correlation_2010 = pearsonr(final_merge_df['MONTHTOTAL'], final_merge_df['2010 Population'])
correlation_2020 = pearsonr(final_merge_df['MONTHTOTAL'], final_merge_df['2020 Population'])

print(f'Pearson correlation coefficient for 2000 Population: {correlation_2000}')
print(f'Pearson correlation coefficient for 2010 Population: {correlation_2010}')
print(f'Pearson correlation coefficient for 2020 Population: {correlation_2020}')
# Out:
# Pearson correlation coefficient for 2000 Population: PearsonRResult(statistic=-0.05701416493773006, pvalue=1.200990276674487e-27)
# Pearson correlation coefficient for 2010 Population: PearsonRResult(statistic=-0.16892017088101535, pvalue=1.4462422278408576e-231)
# Pearson correlation coefficient for 2020 Population: PearsonRResult(statistic=-0.13225462922583556, pvalue=5.870669845927167e-142)

# %%
covariance_matrix = final_merge_df[['MONTHTOTAL', '2000 Population', '2010 Population', '2020 Population']].cov()
print(covariance_matrix)
# Out:
#                    MONTHTOTAL  2000 Population  2010 Population  \
# MONTHTOTAL       6.417762e+09    -5.026854e+07    -3.493744e+08
# 2000 Population -5.026854e+07     1.211277e+08     2.434508e+08
# 2010 Population -3.493744e+08     2.434508e+08     6.665542e+08
# 2020 Population -2.590641e+08     2.353638e+08     6.240126e+08
#
#                  2020 Population
# MONTHTOTAL         -2.590641e+08
# 2000 Population     2.353638e+08
# 2010 Population     6.240126e+08
# 2020 Population     5.978732e+08

# %% [markdown]
# ## Visualizing Population vs. Ridership Trends
#
# We will create scatter plots to visualize the relationship between the population of 2000, 2010 and 2020 and the ridership data. We will generate a line plot to see ridership trends over time by zip code.

# %%
# Scatter plots for each population year vs. ridership
plt.figure(figsize=(10, 6))
sns.scatterplot(x='2000 Population', y='MONTHTOTAL', data=final_merge_df)
plt.title('2000 Population vs. Ridership')
plt.xlabel('2000 Population')
plt.ylabel('Total Rides')
plt.show()

plt.figure(figsize=(10, 6))
sns.scatterplot(x='2010 Population', y='MONTHTOTAL', data=final_merge_df)
plt.title('2010 Population vs. Ridership')
plt.xlabel('2010 Population')
plt.ylabel('Total Rides')
plt.show()

plt.figure(figsize=(10, 6))
sns.scatterplot(x='2020 Population', y='MONTHTOTAL', data=final_merge_df)
plt.title('2020 Population vs. Ridership')
plt.xlabel('2020 Population')
plt.ylabel('Total Rides')
plt.show()

# Line plot to visualize ridership trends over time
final_merge_df['MONTH_BEGINNING'] = pd.to_datetime(final_merge_df['MONTH_BEGINNING'])

plt.figure(figsize=(14, 8))
sns.lineplot(x='MONTH_BEGINNING', y='MONTHTOTAL', data=final_merge_df, hue='zip_code')
plt.title('Ridership Over Time by Zip Code')
plt.xlabel('Date')
plt.ylabel('Total Rides')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# /var/folders/l0/y_hb881s545f0d17b1tv4mt80000gp/T/ipykernel_24297/1165916674.py in <module>
#      25
#      26 plt.figure(figsize=(14, 8))
# ---> 27 sns.lineplot(x='MONTH_BEGINNING', y='MONTHTOTAL', data=final_merge_df, hue='zip_code')
#      28 plt.title('Ridership Over Time by Zip Code')
#      29 plt.xlabel('Date')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     708     p._attach(ax)
#     709
# --> 710     p.plot(ax, kwargs)
#     711     return ax
#     712
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/relational.py in plot(self, ax, kws)
#     469         # Loop over the semantic subsets and add to the plot
#     470         grouping_vars = "hue", "size", "style"
# --> 471         for sub_vars, sub_data in self.iter_data(grouping_vars, from_comp_data=True):
#     472
#     473             if self.sort:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py in iter_data(self, grouping_vars, reverse, from_comp_data)
#     981
#     982         if from_comp_data:
# --> 983             data = self.comp_data
#     984         else:
#     985             data = self.plot_data
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py in comp_data(self)
#    1052                 # Use the converter assigned to the axis to get a float representation
#    1053                 # of the data, passing np.nan or pd.NA through (pd.NA becomes np.nan)
# -> 1054                 with pd.option_context('mode.use_inf_as_null', True):
#    1055                     orig = self.plot_data[var].dropna()
#    1056                 comp_col = pd.Series(index=orig.index, dtype=float, name=var)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_config/config.py in __enter__(self)
#     478
#     479     def __enter__(self) -> None:
# --> 480         self.undo = [(pat, _get_option(pat)) for pat, val in self.ops]
#     481
#     482         for pat, val in self.ops:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_config/config.py in <listcomp>(.0)
#     478
#     479     def __enter__(self) -> None:
# --> 480         self.undo = [(pat, _get_option(pat)) for pat, val in self.ops]
#     481
#     482         for pat, val in self.ops:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_config/config.py in _get_option(pat, silent)
#     144
#     145 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 146     key = _get_single_key(pat, silent)
#     147
#     148     # walk the nested dict
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_config/config.py in _get_single_key(pat, silent)
#     130         if not silent:
#     131             _warn_if_deprecated(pat)
# --> 132         raise OptionError(f"No such keys(s): {repr(pat)}")
#     133     if len(keys) > 1:
#     134         raise OptionError("Pattern matched multiple keys")
#
# OptionError: "No such keys(s): 'mode.use_inf_as_null'"

# %% [markdown]
# ## Ridership Trends Before and During the COVID-19 Pandemic
#
# We analyze the ridership trends before and during the COVID-19 pandemic. The key steps involve defining a start date for the pandemic, categorizing the data into pre-pandemic and pandemic periods, and visualizing the trends using a line plot.

# %%
covid_start_date = '2020-03-01'

final_merge_df['period'] = np.where(final_merge_df['MONTH_BEGINNING'] < covid_start_date, 'pre-pandemic', 'pandemic')

plt.figure(figsize=(14, 8))
sns.lineplot(x='MONTH_BEGINNING', y='MONTHTOTAL', data=final_merge_df, hue='period')
plt.title('Ridership Trends Before and During the COVID-19 Pandemic')
plt.xlabel('Date')
plt.ylabel('Total Rides')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# /var/folders/l0/y_hb881s545f0d17b1tv4mt80000gp/T/ipykernel_24297/1579882382.py in <module>
#       4
#       5 plt.figure(figsize=(14, 8))
# ----> 6 sns.lineplot(x='MONTH_BEGINNING', y='MONTHTOTAL', data=final_merge_df, hue='period')
#       7 plt.title('Ridership Trends Before and During the COVID-19 Pandemic')
#       8 plt.xlabel('Date')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     708     p._attach(ax)
#     709
# --> 710     p.plot(ax, kwargs)
#     711     return ax
#     712
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/relational.py in plot(self, ax, kws)
#     469         # Loop over the semantic subsets and add to the plot
#     470         grouping_vars = "hue", "size", "style"
# --> 471         for sub_vars, sub_data in self.iter_data(grouping_vars, from_comp_data=True):
#     472
#     473             if self.sort:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py in iter_data(self, grouping_vars, reverse, from_comp_data)
#     981
#     982         if from_comp_data:
# --> 983             data = self.comp_data
#     984         else:
#     985             data = self.plot_data
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py in comp_data(self)
#    1052                 # Use the converter assigned to the axis to get a float representation
#    1053                 # of the data, passing np.nan or pd.NA through (pd.NA becomes np.nan)
# -> 1054                 with pd.option_context('mode.use_inf_as_null', True):
#    1055                     orig = self.plot_data[var].dropna()
#    1056                 comp_col = pd.Series(index=orig.index, dtype=float, name=var)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_config/config.py in __enter__(self)
#     478
#     479     def __enter__(self) -> None:
# --> 480         self.undo = [(pat, _get_option(pat)) for pat, val in self.ops]
#     481
#     482         for pat, val in self.ops:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_config/config.py in <listcomp>(.0)
#     478
#     479     def __enter__(self) -> None:
# --> 480         self.undo = [(pat, _get_option(pat)) for pat, val in self.ops]
#     481
#     482         for pat, val in self.ops:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_config/config.py in _get_option(pat, silent)
#     144
#     145 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 146     key = _get_single_key(pat, silent)
#     147
#     148     # walk the nested dict
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_config/config.py in _get_single_key(pat, silent)
#     130         if not silent:
#     131             _warn_if_deprecated(pat)
# --> 132         raise OptionError(f"No such keys(s): {repr(pat)}")
#     133     if len(keys) > 1:
#     134         raise OptionError("Pattern matched multiple keys")
#
# OptionError: "No such keys(s): 'mode.use_inf_as_null'"

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7862ac62-05ae-412f-9bc1-59d586e87203' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
